# %%
import pandas as pd
import numpy as np 
from collections import Counter as c
from sklearn.preprocessing import LabelEncoder

from pandas import Series as s, DataFrame as df
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model, metrics 
from sklearn.linear_model import LogisticRegression 
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

# %%
data = pd.read_csv("abhilasha_dataset_updated.csv" , encoding = "ISO-8859-1" )

# %%
data.shape
# Out:
# (5436, 2)

# %%
data.columns
# Out:
# Index(['description', 'category'], dtype='object')

# %%
data.head(2)
# Out:
#           description category
# 0  Hi This is Dheeraj   ignore
# 1  Dheeraj joining in   ignore

# %%
data.isnull().sum()
# Out:
# description    0
# category       1
# dtype: int64

# %%
data.dropna(subset=['category'], how='all', inplace = True)

# %%
data.isnull().sum()
# Out:
# description    0
# category       0
# dtype: int64

# %%
cleanup_nums = {"category":     {"ignore": 1
                                  , "decision": 2
                                  , "action point": 3
                                  , "key point": 4
                                  , "key notes": 5
                                  , "ingore": 6
                                  , "key points": 7
                                  , "action plan": 8
                                 }}

# %%
c(data.category)
# Out:
# Counter({'ignore': 572,
#          'decision': 1903,
#          'action point': 1645,
#          'key point': 1311,
#          'key notes': 1,
#          'ingore': 1,
#          'key points': 1,
#          'action plan': 1})

# %%
enc = LabelEncoder()

# %%
from sklearn.preprocessing import OneHotEncoder
#enc=OneHotEncoder(sparse=False)

# %%
data["category_label"] = enc.fit_transform(data["category"])

# %%
#data["category_label"]

# %%
data[["category_label" , "category"]].head(10)
# Out:
#    category_label category
# 0               3   ignore
# 1               3   ignore
# 2               3   ignore
# 3               3   ignore
# 4               3   ignore
# 5               3   ignore
# 6               3   ignore
# 7               3   ignore
# 8               3   ignore
# 9               3   ignore

# %%
#data.replace(cleanup_nums, inplace=True)

# %%
type(data.category)
# Out:
# pandas.core.series.Series

# %%
x = data.loc[:,["description"]]
y = data["category_label"]

# %%
a = data.iloc[:,0]
b = data.iloc[:,-1]

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
data.dtypes
# Out:
# description       object
# category          object
# category_label     int64
# dtype: object

# %%
#b

# %%
#model = LogisticRegression()

# Instantiate the classifier
model = GaussianNB()

# %%
x_train, x_test , y_train , y_test = train_test_split(x ,b , test_size = 0.3 , random_state = 1)

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-4719cf73997a> in <module>()
# ----> 1 model.fit(x_train,y_train)
#
# ~/miniconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     181             Returns self.
#     182         """
# --> 183         X, y = check_X_y(X, y)
#     184         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     185                                  sample_weight=sample_weight)
#
# ~/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     446         # make sure we actually converted to numeric:
#     447         if dtype_numeric and array.dtype.kind == "O":
# --> 448             array = array.astype(np.float64)
#     449         if not allow_nd and array.ndim >= 3:
#     450             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'Secondly  we shall look at \x85'

# %%
#y_trai

# %%
c(data.category)
# Out:
# Counter({3: 572, 2: 1903, 1: 1645, 6: 1311, 5: 1, 4: 1, 7: 1, 0: 1})

# %%
# Instantiate the classifier
gnb = GaussianNB()

# %%
#x

# %%
c(data.description)
# Out:
# Counter({'Hi This is Dheeraj': 1,
#          'Dheeraj joining in': 1,
#          'Dheeraj here': 1,
#          "Let\\'s wait for David and Sarma to join": 1,
#          "Let\\'s get started in couple of min": 1,
#          'Your voice is not clear': 1,
#          'Can you join back again': 1,
#          'Can you mute your call': 1,
#          'Can everyone go on mute while not speaking': 1,
#          "Ok  5 min in the call   let\\'s get started": 1,
#          'share your screen': 1,
#          'You need to speed up the work': 1,
#          "Let\\'s discuss about the issues": 1,
#          'Have you been able to complete the presentation': 1,
#          'Can you update the project plan': 1,
#          'Can you give me the status of work assigned to you Ravi': 1,
#          'I think we should convert this meeting to bi-weekly': 1,
#          "Let\\'s go for outing": 1,
#          "Let\\'s take it offline": 1,
#          'I think we are deviating from the agenda': 1,
#          "What is the agenda for today\\'s call": 1,
#          "Let\\'s not bother about that": 1,
#          'Can you open the Issue log': 1,
#          'In the last meeting we discussed to close this item': 1,
#          'Can you take this as an action point point': 1,
#          'Can you please explain on the board': 1,
#          'I am going to finish this by EOD today': 1,
#          'I just have 5 min ': 1,
#          'I need to join another call in 15 min': 1,
#          'What I want to see if clear plan of action point': 1,
#          'I need a demo on this ': 1,
#          'How much time is it going to take': 1,
#          'Are we good with this': 1,
#          'You are right Mark': 1,
#          'I think we need to do a PoC on this': 1,
#          'Is there any major challenge you see in this': 1,
#          'That is what we are saying': 1,
#          'Are we talking about competency gap here': 1,
#          'Just to summarize this': 1,
#          'Can you send a detailed mail around this': 1,
#          'We need more resources': 1,
#          'We onboarded Suneel for the role of DBA': 1,
#          'Vendors have been finalized for this': 1,
#          'The Design document has been approved': 1,
#          'We plan to finish the development in decision weeks': 1,
#          'We plan to finish the design in decision days': 1,
#          "Let\\'s finish the design in 5 days": 1,
#          'This is not good': 1,
#          'The feedback is good for the design': 1,
#          'Can you name the roadblocks': 1,
#          'If you are not confident lets not do it': 1,
#          'We will strike off the item action point here': 1,
#          'Lets discuss this for 5 min and resolve this issue': 1,
#          'I am not interested in Prototype': 1,
#          'The purpose of the meeting is not clear': 1,
#          'Is it a holiday in India on 15th Aug': 1,
#          'It does not make sense to wait': 1,
#          'The code is failing for the second test case': 1,
#          'I am cancelling this meeting': 1,
#          "Let\\'s close the call": 1,
#          "Ravi to take David\\'s task for this week": 1,
#          'What is the time in Australia currently': 1,
#          'action point item 1 is not relevant': 1,
#          "Let\\'s not do it": 1,
#          'everyone has arrived now  so Let us get started.': 1,
#          'If we are all here  Let us start the meeting.': 1,
#          'Now that everyone is here  shall we begin?': 1,
#          'Shall we get down to business?': 2,
#          'Well  since everyone is here  we should get started.': 1,
#          'Okay  we have a lot to cover today  so we really should get started.': 1,
#          'Hello everyone. Thank you for coming today.': 1,
#          'Okay  Let us begin. Firstly  I had like to welcome you all.': 1,
#          'Thank you all for coming at such short notice.': 1,
#          'I really appreciate your attendance to this meeting.': 1,
#          'For those of you who do not know me yet  I am \x85': 1,
#          'Please join me in welcoming \x85': 1,
#          'I had like to extend a warm welcome to \x85': 1,
#          'We are pleased to welcome \x85': 1,
#          'Firstly  I had like to introduce \x85': 1,
#          'For anyone who hasn\x92t met our new \x85 yet  this is \x85': 1,
#          'It\x92s a pleasure for me to welcome \x85': 1,
#          'I had like to take a moment to introduce \x85': 1,
#          'I know most of you  but there are a few unfamiliar faces. I am \x85': 1,
#          'Sarma has kindly agreed to take the minutes today.': 1,
#          'Sarma will be presenting the \x85': 1,
#          'Sarma has kindly agreed to give us a report on \x85': 1,
#          'Sarma  would you mind taking notes / taking the minutes today please?': 1,
#          'Sarma will lead (topic) from the agenda.': 1,
#          'Sarma  would you like to kick off with \x85?': 1,
#          'Unfortunately  Margaret cannot join us today. She was called away on urgent business.': 1,
#          'Mark will be taking the minutes today  as Sarah is at home with a fever.': 1,
#          'I have received apologies for absence from \x85': 1,
#          'If you notice anyone missing  please let Mark know so he can make a note of it.': 1,
#          'We are here today to talk about \x85': 2,
#          'We are here to discuss \x85': 2,
#          'Our main aim today is to \x85': 2,
#          'I\x92ve called this meeting today in order to \x85': 2,
#          'As you can see here on the agenda \x85': 2,
#          'Firstly  we shall be talking about \x85': 2,
#          'First of all  we shall discuss \x85': 2,
#          'After that  we shall be looking at \x85': 2,
#          'Followed by \x85': 2,
#          'If time allows  we will also cover \x85': 2,
#          'Then  I will be handing it over to \x85 for \x85': 2,
#          'Secondly  we shall look at \x85': 2,
#          'Next  I will ask you for (feedback  comments  your opinion  your views  suggestions  ideas) on \x85': 2,
#          'And finally  we shall discuss \x85': 1,
#          'That\x92s a valid point but we will discuss that in more detail at a later date.': 2,
#          'Okay  Let us talk more about that later on.': 2,
#          'I am afraid we shall have to come back to this later.': 2,
#          'We were running short on time  so Let us move on to the next topic.': 2,
#          'We were running behind now  so Let us skip to the next point on the agenda.': 2,
#          'I am afraid we only have 10 minutes left  so Let us move on to\x85.': 2,
#          'we have spent too long on this issue now  Let us discuss it in more detail after this meeting.': 2,
#          'I think we shall have to leave that there for now and move on to\x85.': 2,
#          'We were pushed for time  so Let us discuss\x85.': 2,
#          'Let us try to stay on topic  that can be discussed another time.': 2,
#          'You can discuss that amongst yourselves after the meeting.': 2,
#          'This matter is not on today\x92s agenda  Let us leave it for next time.': 2,
#          'Let us save this for another meeting.': 2,
#          'Getting back to the task at hand\x85.': 2,
#          'I couldn\x92t agree with you more (I agree)': 1,
#          'I completely agree with \x85': 1,
#          'Could I just say one thing please?': 1,
#          'If I could just come in here \x85': 1,
#          'I would just like to add \x85': 1,
#          'May I come in here please?': 1,
#          'Sorry  could you speak up a little please? I can\x92t hear you at the back.': 1,
#          'If I could have a chance to speak for a moment please.': 1,
#          'I am glad you brought that up. I had like to add \x85': 1,
#          'I am afraid I had have to disagree with you on that.': 1,
#          'I would just like to say that \x85': 1,
#          'Excuse me for interrupting \x85': 1,
#          'I really feel that \x85': 1,
#          'The way I see things \x85': 1,
#          'In my opinion \x85': 1,
#          'Sarma  could you please tell us how \x85 is progressing?': 1,
#          'Sarma  how is the \x85 coming along?': 1,
#          'Next  Sarma will talk us through \x85': 1,
#          '(Name  have you managed to complete the \x85?': 1,
#          'Sarma  when can we expect to hear about \x85?': 1,
#          'Has everyone received a copy of \x85?': 1,
#          'Sarma  can we have your input on \x85 please?': 1,
#          'How do you feel about \x85?': 1,
#          'Are you positive that \x85?': 1,
#          'What do you think about \x85': 1,
#          'What are your views on \x85?': 1,
#          'Now  I had like to hand over to Sarma  who will talk about \x85': 1,
#          'This brings us to the next topic on the agenda  which will be introduced by Sarma.': 1,
#          'Why do not we move on to \x85': 1,
#          'If no one has anything else to add  Let us move on to \x85': 1,
#          'I do not quite follow you. What exactly do you mean?': 1,
#          'I do not see what you mean. Could you elaborate please?': 1,
#          'I am afraid I do not quite understand what you were getting at.': 1,
#          'Could you please explain to me how that is going to work?': 1,
#          'Do you mean that \x85?': 1,
#          'So what you were saying is that \x85 (repeat what they said to get confirmation)': 1,
#          'You did say \x85 didn\x92t you?': 1,
#          'Could you spell that please?': 1,
#          'Would you mind spelling that for me please?': 1,
#          '(repeat what they said in your own words) \x85 is that what you mean?': 1,
#          'Is it true that \x85?': 1,
#          'Correct me if I am wrong please  you were saying \x85 (reiterate what they said)': 1,
#          'Is there any other business?': 1,
#          'Does anyone have any other business?': 1,
#          'Any other business?': 1,
#          'Would anyone like to make any final points?': 1,
#          'If there are no further points  I had like to bring the meeting to a close.': 1,
#          'Before we close the meeting  I had like to briefly summarise the main points \x85': 1,
#          'Let me quickly go over today\x92s main points.': 1,
#          'To sum up \x85': 1,
#          'Right  why do not we summarise what we have agreed on today.': 1,
#          'Shall I go over the main points before we adjourn?': 1,
#          'I guess that will be all for today  thank you for taking part.': 1,
#          'I think we should finish here.': 1,
#          'We seem to have been very efficient today  so Let us wrap up early.': 1,
#          'We have covered everything on the agenda  so Let us end it here.': 1,
#          'If there is nothing else to add  I had like to adjourn the meeting.': 1,
#          'If there are no other comments  I had like to wrap this meeting up.': 1,
#          'It looks like we have finished ahead of schedule  so Let us finish up here.': 1,
#          'I am afraid We were going to have to cut this meeting short. I\x92ve just been informed of an urgent matter that needs to be dealt with immediately.': 1,
#          'I am afraid we shall have to end this meeting here. Let us rearrange and continue this discussion another time.': 1,
#          'Thank you all for your input today.': 1,
#          'Thank you for your participation.': 1,
#          'Let us end this here  shall we? I am sure you all have other important work to get back to.': 1,
#          'Before you leave  please remember to sign the attendance sheet': 1,
#          'I almost forgot to mention\x85.': 1,
#          'I had like to thank Sarma for \x85': 1,
#          'Sorry  could I please have your attention for one more moment. I forgot to say\x85': 1,
#          'Before we go  Let us put our hands together for (clap or say congratulations)\x85.': 1,
#          'Most of you probably know this already  but I had like to formally congratulate\x85.': 1,
#          'Please do not forget to hand in your votes by the end of the week.': 1,
#          'I look forward to receiving emails from you all about your final vote.': 1,
#          'The minutes of the meeting will be sent to you all by (persons name and/or time/date) \x85': 1,
#          'If anyone has any further questions  or would like to give any feedback privately  then please feel free to email me.': 1,
#          "I do not think you\\'ve met Daniel": 1,
#          'Have you all received a copy of the agenda': 1,
#          'There are three items on the agenda. First': 1,
#          'Shall we take the points in this order?': 2,
#          'If you do not mind I had like to . go in order (OR)': 1,
#          'sexy lady in the town': 1,
#          'jungle bool': 1,
#          'dude what is this': 1,
#          'hey man  whats up': 1,
#          'cool dude': 1,
#          'Is this article of association.': 1,
#          'decrease in the premium anything that<font color': 1,
#          'indicated in red is a change': 1,
#          'if you go over a primary font colour': 1,
#          'cooking that next time must be special': 1,
#          'that would be a special okay': 1,
#          'choices every I mean she was good': 1,
#          'urgent care program it would go': 1,
#          'furthered say the same and then you can tell': 1,
#          'way would you prefer specialty': 1,
#          'for human sensor now number': 1,
#          'the current time now to that': 1,
#          'change and so is coming back for revenge': 1,
#          'work and then there are so many options': 1,
#          'differences easy sending right now for the love': 1,
#          'people did utilize my cars': 1,
#          'we the provider so the concern is eliminated.': 1,
#          'I have talked about this long back': 1,
#          'Coverage but it needs to be essentially': 1,
#          'loose changes especially the same for both size': 1,
#          'coverage or is it going to be seen as an key point player': 1,
#          'where it happened and what are the impace': 1,
#          'all this information are stored': 1,
#          'we got some really negative environment': 1,
#          'feedback they were happier with the VSP': 1,
#          'involvement I met back at we can do this': 1,
#          'Individually so I I do not know.': 1,
#          'The California Department of Motor Vehicles will allow autonomous cars': 1,
#          'released its revised regulations today governing the safe': 1,
#          'which will then begin enforcing them': 1,
#          'California is an obvious hotbed for autonomous vehicle testing': 1,
#          'Google and Uber that are developing fleets': 1,
#          'self-driving cars for public use': 1,
#          'safety drivers are licensed to test those vehicles': 1,
#          'companies would be allowed to deploy cars': 1,
#          'without any human behind the wheel': 1,
#          'The rules are a stark departure from': 1,
#          'the original proposal issued in decision015': 1,
#          'Those draft regulations would have put': 1,
#          'But then in May the agency': 1,
#          'putting out a new proposal that would not only': 1,
#          'allow for the testing of self-driving cars without': 1,
#          'including new provisions requiring manufacturers': 1,
#          'to notify local governments when they plan': 1,
#          'on testing autonomous vehicles in their cities': 1,
#          'a new template for manufacturers to report': 1,
#          'the number of times the vehicle forced': 1,
#          'the human driver to take control because it couldnot': 1,
#          'safely navigate the conditions on the road.': 1,
#          'And operators will be required to report to the state': 1,
#          'when some technological upgrades are made': 1,
#          'such as a change in the level of automation': 1,
#          'The state is not changing its prohibition': 1,
#          'n the testing of autonomous trucks arguing that': 1,
#          'a separate rule-making process will be needed to allow for': 1,
#          'the testing of self-driving vehicles.': 1,
#          'evolve does that get us out of this that': 1,
#          'math about how to do current plans are': 1,
#          'always been so work really important to': 1,
#          'any questions everybody waits': 1,
#          'it was well maintained': 1,
#          'negotiate this out of a contract': 1,
#          'be like yeah yeah would not happen': 1,
#          'Angolan contract that I really that': 1,
#          'I thought why why if you are changing': 1,
#          'wrong on make on the way you speak': 1,
#          'vision insurance and I mean the feedback': 1,
#          'the people that were': 1,
#          'were pretty vocal yeah and it': 1,
#          'referrals welfare and there': 1,
#          'o Bilborough early than the age': 1,
#          'word is water more fun': 1,
#          'when they emails that that': 1,
#          'me at one time so we are going to do': 1,
#          'I just came up I wanna change': 1,
#          'come on you know the pacific-1decision online': 1,
#          'referral little mission': 1,
#          'options like a formal the the ER': 1,
#          'urgent care proteins are kinda would fit': 1,
#          'a huge industry right but it is an': 1,
#          'increase is there any wiggle room fit': 1,
#          'matching is close to close a break over': 1,
#          'ok methodology what that does is going': 1,
#          'calories to too much of it': 1,
#          'to them as well why would': 1,
#          'get bombarded by questions all along': 1,
#          'deal for it yes it will': 1,
#          'know should be on their children': 1,
#          'entures are questions that': 1,
#          'little bit about everything': 1,
#          'ventures are questions that': 1,
#          'received anything from any of the guy': 1,
#          'I?m more than happy to speak with you': 1,
#          'Please stop by my office next week': 1,
#          'Would you like a drink?': 1,
#          'We?re going to be late': 1,
#          'But I do need help with directions': 1,
#          ' I was just thinking about you': 1,
#          'how are things at the office': 1,
#          'Can you hear me now': 1,
#          'I haven?t seen you in ages': 1,
#          'what do you think of this shirt': 1,
#          'It?s freezing outside': 1,
#          'What happened to the weather report': 1,
#          'Can we go inside': 1,
#          ' I?ll be your waiter today': 1,
#          'Yes. I?ll have iced tea please': 1,
#          'I think we?re ready': 1,
#          'What seems to be the problem': 1,
#          'I also have a headache': 1,
#          'How long have you had these symptoms': 1,
#          ' And I?m really tired too': 1,
#          ' It sounds like you?ve got the flu': 1,
#          'Make sure you drink lots of fluids': 1,
#          'Are we all on?': 1,
#          'Can I ask that we all state our names please': 1,
#          'Can everybody hear me': 1,
#          'Could you speak more slowly please': 1,
#          'Could you repeat that please': 1,
#          'Would you mind spelling that for me please': 2,
#          'Could you explain that in another way please': 1,
#          'I?m afraid I didn?t get that': 1,
#          'I need to leave for ten minutes. Is that okay with everyone?': 1,
#          'I?m back on the line again.': 1,
#          'just coming back in here thanks everyone': 1,
#          'I didn?t quite hear that sorry ': 1,
#          'I didn?t catch that last bit': 1,
#          'can you say that again': 1,
#          'Am I to understand that': 1,
#          'Sorry but just to clarify': 1,
#          'When are you free': 1,
#          'I have  a concern about the people that leaving the projects very soon': 1,
#          'On his desk is a mass of books and papers.': 1,
#          'the sheer volume of traffic on our motorways': 1,
#          'his portion of the inheritance': 1,
#          'A cardinal rule or quality is the one that is considered to be the most important.': 1,
#          'Put all complex motions and resolutions in writing': 1,
#          'Listen to the remarks of others with an open mind': 1,
#          'Address all remarks through the chair.': 2,
#          'Avoid emotional and tactless remarks.': 1,
#          'Put all complex motions and resolutions in writing.': 1,
#          'Listen to the remarks of others with an open mind.': 1,
#          'Avoid asking the recording secretary to run errands for me during the meeting.': 1,
#          'Be familiar with the agreed upon procedures used to govern the meeting.': 1,
#          ' but the current survey is slanted toward the existing Rust community and does not give us as much insight into people who have not yet gotten on board': 1,
#          "i was wondering how best to address that; it\\'d be great to use that high profile post to get more insight *beyond* the current community": 1,
#          'but it might want to be an entirely different and much shorter survey': 1,
#          ' there?s a little bit of the new user stuff at the end? we could move things around and expand for new users': 1,
#          'how is the wether i': 1,
#          'are u coming to bagalore': 1,
#          'had your lunch': 1,
#          'how about your friends': 1,
#          'My son just took a low-paying internship position with a large company. He was happy to get his foot in the door at a well-known respected company.': 1,
#          'Winning the lottery is a long shot but millions of people still buy lottery tickets.': 1,
#          'If you want to fill out form 5decision-E and send it to the government you have to do it using snail mail. They do not allow you to scan the document.': 1,
#          'We offered them a very generous price on their first order and everything shipped on time. We really started off on the right foot.': 1,
#          'Please join me in welcoming Daniel': 2,
#          'We were pleased to welcome Daniel': 2,
#          "It\\'s a pleasure to welcome Daniel": 2,
#          'I had like to introduce Daniel': 2,
#          'We were here today to': 1,
#          "I\\'ve called this meeting in order to .": 2,
#          "I am afraid.Daniel can\\'t be with us today. She is in.": 2,
#          'I have received apologies for the absence of Daniel who is in (place).': 1,
#          "I am afraid Peter can\\'t be with us today. He\\'s in London meeting with clients but will be back next week.": 1,
#          'skip item key point and move on to item action point': 2,
#          'I suggest we go round the table first.': 2,
#          'Introducing the First Item on the Agenda': 2,
#          "So let\\'s start with": 1,
#          'Shall we start with. .': 1,
#          'So the first item on the agenda is': 1,
#          'Pete would you like to kick off?': 1,
#          'Martin would you like to introduce this item?': 1,
#          'I think that covers the first item.': 1,
#          'If nobody has anything else to add': 1,
#          'I think that covers the important points of the merger.': 1,
#          'The next item on the agenda is': 1,
#          'To sum up .': 1,
#          'In brief': 1,
#          'Shall I go over the main points?': 2,
#          'I had like to thank Marianne and Jeremy for coming over from London.': 1,
#          'Thank you all for attending.': 1,
#          'Thanks for your participation.': 1,
#          'Opening the Meeting': 1,
#          'Welcoming and Introducing Participants': 1,
#          'Stating the Principal Objectives of a Meeting': 1,
#          'Giving Apologies for Someone Who is Absent': 2,
#          'Introducing the Agenda': 2,
#          'Summarizing': 2,
#          'Finishing Up': 1,
#          'Thanking Participants for Attending': 1,
#          'Closing the Meeting': 1,
#          'Good morning/afternoon everyone.': 1,
#          "If we are all here let\\'s get started / start the meeting / start.": 1,
#          'Welcoming and Introducing': 1,
#          'I had like to extend a warm welcome to Daniel': 1,
#          'Unfortunately Daniel . will not be with us to day because he .': 1,
#          'I have received apologies for absence from Daniel who is in (place).': 1,
#          'Jack can you tell us how the XYZ project is progressing?': 1,
#          'Moving Forward': 1,
#          'Have you all received a copy of the agenda?': 1,
#          'There are X items on the agenda. First . second . third . lastly .': 1,
#          'If you do not mind I had like to go in order today.': 1,
#          'I suggest we take item decision last.': 2,
#          "Let\\'s make sure we finish by .": 1,
#          'I had suggest we .': 1,
#          'There will be five minutes for each item.': 1,
#          "We\\'ll have to keep each item to key point5 minutes. Otherwise we\\'ll never get through.": 1,
#          'Shall we start with .': 1,
#          'I think that takes care of the first item.': 1,
#          'Shall we leave that item?': 2,
#          'Why do not we move on to.': 1,
#          'If nobody has anything else to add lets .': 1,
#          'Next Item': 1,
#          "Let\\'s move onto the next item": 2,
#          "Now that we\\'ve discussed X let\\'s now .": 1,
#          "The next item on today\\'s agenda is.": 1,
#          'Now we come to the question of.': 2,
#          'Giving Control to the Next Participant': 1,
#          'I had like to hand over to Daniel who is going to lead the next point.': 1,
#          'Next Daniel is going to take us through .': 1,
#          'Now I had like to introduce Daniel who is going to .': 1,
#          "Right it looks as though we\\'ve covered the main items.": 1,
#          'If there are no other comments I had like to wrap this meeting up.': 1,
#          "Let\\'s bring this to a close for today.": 1,
#          'Is there Any Other Business?': 2,
#          "Getting the Chairperson\\'s Attention": 1,
#          '(Mister/Madam) chairman.': 1,
#          'May I have a word?': 2,
#          'If I may I think.': 2,
#          'Excuse me for interrupting.': 2,
#          'May I come in here?': 1,
#          'Giving Opinions': 1,
#          'I am positive that.': 2,
#          'I (really) feel that.': 2,
#          'In my opinion.': 3,
#          'The way I see things.': 2,
#          'If you ask me. I tend to think that.': 2,
#          'Asking for Opinions': 1,
#          'Are you positive that.': 1,
#          'Do you (really) think that.': 2,
#          'Daniel can we get your input?': 2,
#          'How do you feel about.?': 3,
#          'Commenting': 1,
#          "That\\'s interesting .": 1,
#          'I never thought about it that way before.': 1,
#          'Good point!': 3,
#          'I get your point.': 3,
#          'I see what you mean.': 3,
#          'Let me spell out.': 1,
#          'Have I made that clear?': 1,
#          'Do you see what I am getting at?': 1,
#          'Let me put this another way.': 1,
#          'I had just like to repeat that.': 1,
#          'Requesting Information': 1,
#          'Please could you.': 2,
#          'I had like you to.': 2,
#          'Would you mind.': 2,
#          'I wonder if you could.': 2,
#          'Asking for Repetition': 1,
#          "I am afraid I didn\\'t understand that. Could you repeat what you just said": 1,
#          "I didn\\'t catch that. Could you repeat that please": 1,
#          'I missed that. Could you say it again please': 1,
#          'Could you run that by me one more time': 1,
#          'Asking for Clarification': 1,
#          'I do not quite follow you. What exactly do you mean': 1,
#          'I am afraid I do not quite understand what your are getting at.': 1,
#          'Could you explain to me how that is going to work?': 2,
#          'I do not see what you mean. Could we have some more details please?': 2,
#          "You did say next week didn\\'t you? (\\'did\\' is stressed)": 1,
#          'Do you mean that.': 1,
#          'Asking for Spelling': 1,
#          'Could you spell that please': 1,
#          'Asking for Contributions': 1,
#          'We have not heard from you yet Daniel.': 1,
#          'What do you think about this proposal': 1,
#          'Would you like to add anything Daniel': 1,
#          'Has anyone else got anything to contribute': 1,
#          'Are there any more comments': 1,
#          'Correcting Information': 1,
#          'Sorry I think you misunderstood what I said.': 1,
#          "Sorry that\\'s not quite right.": 2,
#          'I am afraid you do not understand what I am saying.': 2,
#          "That\\'s not quite what I had in mind.": 2,
#          "That\\'s not what I meant.": 2,
#          'Well that seems to be all the time we have today.': 1,
#          'Please be brief.': 1,
#          "I am afraid we\\'ve run out of time.": 1,
#          "I am afraid that\\'s outside the scope of this meeting.": 1,
#          "Let\\'s get back on track why do not we?": 1,
#          "That\\'s not really why We were here today.": 1,
#          "Why do not we return to the main focus of today\\'s meeting.": 1,
#          "We\\'ll have to leave that to another time.": 1,
#          'We were beginning to lose sight of the main point.': 1,
#          'Keep to the point please.': 1,
#          'I do not remember being an issue did to that it so there we have it.': 1,
#          'apologies for joining the late in meeting': 1,
#          'Bye-laws always work': 1,
#          'These are all casting vote guys': 1,
#          'List of executive for the invite': 1,
#          'It was wonderful and extraordinary meeting': 1,
#          'You shold not lisitin to the ex officio': 1,
#          'These Guillotine need to be in the change': 1,
#          'These are honoary post  keep in mind': 1,
#          'Information which is in meeting is not really correct': 1,
#          'Intra vires are changing the process': 1,
#          'This is not like life on the table': 1,
#          'Mark these in lovvying': 1,
#          'Have you checked the quorum': 1,
#          'Please ask my secretary to help you in that': 1,
#          'Having shelve is a good things': 1,
#          'It might be sine die': 1,
#          'You should write to standing committee': 1,
#          'These batch of products are on standing orders': 1,
#          'That has been taken as read': 1,
#          'It seems like ultra vires': 1,
#          'do not ask unanimous questions': 1,
#          'Your objective should be clear': 1,
#          'We are getting very good feedback from Clients': 1,
#          'Next week so three days': 1,
#          'option it is give every girl that would': 1,
#          'universes come off the ride': 1,
#          'It?s a pleasure to meet you': 1,
#          'Thank you so much for helping us': 1,
#          ' I will be able to answer your questions': 1,
#          ' I?ll see you later then': 1,
#          ' That?s my field too': 1,
#          'I work for the United Nations': 1,
#          'Welcome everybody': 1,
#          'my name is Shyam': 1,
#          'I?m the designer for XYZ Video': 1,
#          ' I?m going to keep this brief': 1,
#          'I know you?re all busy people': 1,
#          'I?m going to make this quick for you': 1,
#          'Today I?m here to talk to you about': 1,
#          'I?m delighted to be here today to tell you about': 1,
#          'Today I would like to outline our plans for': 1,
#          'I?ll start with some general information on': 1,
#          'I will be glad to answer any questions': 1,
#          'you may have at the end of this presentation.': 1,
#          'Well that brings me to the end of my presentation': 1,
#          'thanks so much for listening': 1,
#          'It was a real pleasure being here today': 1,
#          'Goodbye and thank you': 1,
#          'Well that?s it from me': 1,
#          'Thanks a lot': 1,
#          'Sorry I interrupted you. ': 1,
#          'You were saying': 1,
#          'Please go on': 1,
#          'After you': 1,
#          'I?m sorry but could you speak up a little': 1,
#          'So what we?re saying is': 1,
#          'That?s an excellent point': 1,
#          'can I tell you how we see it': 1,
#          'I understand that we can?t do that': 1,
#          'I hear what you?re saying': 1,
#          'we can?t budge': 1,
#          'your earliest convenience': 1,
#          'Are you free to talk again next week': 1,
#          'When can we talk about this again': 1,
#          'What time was the meeting again': 1,
#          'I have another appointment that conflicts with your meeting': 1,
#          ' I will not be able to make it': 1,
#          'I have a question': 1,
#          'Why is marketing not handling the portion on end user analysis': 1,
#          'They usually did this work in the past': 1,
#          'Did you think the meeting went ok': 2,
#          'Can you provide feedback on the meeting we just had': 2,
#          'Did you find the meeting useful': 2,
#          'Did the meeting help to clarify the current situation': 2,
#          'Is there any part of our discussion during the meeting  ': 1,
#          'you are still unsure about': 1,
#          'I thought the presentation went well': 1,
#          ' You provided great information and I think everyone was impressed': 1,
#          'The meeting went well': 1,
#          'The whole presentation went pretty well': 1,
#          'our weekly meeting is pretty dull': 1,
#          'Most of the time our weekly meeting is pretty dull': 1,
#          'I have had more than my share of adventures.': 1,
#          'She had to be held back by main force.': 1,
#          'AGM: Annual General Meeting: all members are usually eligible to attend': 1,
#          'Apologies: excuses given in advance for inability to attend a meeting': 1,
#          "Articles of Association: rules required by Company law which govern a company\\'s activities": 1,
#          'Attendance list: in some committees a list is passed round to be signed as a record of attendance': 1,
#          "Bye-laws: rules regulating an organisation\\'s activities": 1,
#          "Casting vote: by convention some committee chairmen may use a \\'casting vote\\' to reach a decision if votes are equally divided": 1,
#          'Chairman: leader or person given authority to conduct a meeting': 1,
#          'Committee: a group of people usually elected or appointed who meet to conduct agreed business and report to a senior body': 1,
#          'Consensus: agreement by general consent no formal vote being taken': 1,
#          'Constitution: set of rules governing activities of voluntary bodies': 1,
#          'Information Point ofÿ: the drawing of attention in a meeting to a relevant item of fact': 1,
#          'Intra vires: within the power of the committee or meeting to discuss carry out': 1,
#          "Lobbying: a practice of seeking members\\' support before a meeting": 1,
#          'Mover: one who speaks on behalf of a motion': 1,
#          "Nem con: from Latin literally \\'no one speaking against\\'": 1,
#          'Opposer: one who speaks against a motion': 1,
#          'Order point of: the drawing of attention to a breach of rules or procedures': 1,
#          'Other business: either items left over from a previous meeting or items discussed after the main business of a meeting': 1,
#          "Point of order: proceedings may be interrupted on a \\'point of order\\' if procedures or rules are not being kept to in a meeting": 1,
#          "Proxy: literally \\'on behalf of another person\\' - proxy vote": 1,
#          'Quorum: the number of people needed to be in attendance for a meeting to be legitimate and so commence': 1,
#          'Refer back:ÿto pass an item back for further consideration': 1,
#          "Seconder: one who supports the \\'proposer\\' of a motion or proposal by \\'seconding\\' it": 1,
#          'Secretary: committee official responsible for the internal and external administration of a committee': 1,
#          'Secret ballot: a system of voting in secret': 1,
#          'Shelve: to drop a motion which has no support': 1,
#          "Sine die:ÿfrom Latin literally \\'without a day\\' that is to say indefinitely e.g. \\'adjourned sine die\\'.": 1,
#          'Ultra vires: beyond the authority of the meeting to consider': 1,
#          'Soÿlet?s start with item number one': 1,
#          'We have a number of important matters on the agenda today.': 1,
#          'increasing our cooperation on a global level': 1,
#          'The first itemÿon the agenda that we need to discuss today': 1,
#          'Ram Says': 1,
#          'Sarma Suggested': 2,
#          'One minute please it seems we haven?t discussedÿthe individual project deadlines': 1,
#          'Read the agenda and all accompanying material including the previous minutes before the meeting': 1,
#          'Bring all necessary reports and information to the meeting': 1,
#          'Be prepared to discuss the items on the agenda': 1,
#          'Avoid emotional and tactless remarks': 1,
#          'Address all remarks through the chair': 1,
#          'Give everyone an equal chance to speak': 1,
#          'Begin the meeting with introductions with special attention paid to newcomers.': 1,
#          "Meeting Chairman:ÿIf we are all here let\\'s get started. First of all I had like you to please join me in welcoming Jack Peterson our Southwest Area Sales Vice President.": 1,
#          "Jack Peterson:ÿThank you for having me I am looking forward to today\\'s meeting.": 1,
#          'Meeting Chairman:ÿÿI had also like to introduce Margaret Simmons who recently joined our team.': 1,
#          'Margaret Simmons:ÿMay I also introduce my assistant Bob Hamp.': 1,
#          "Meeting Chairman:ÿÿWelcome Bob. I am afraid our national sales director Anne Trusting can\\'t be with us today. She is in Kobe at the moment developing our Far East sales force.": 1,
#          'BEGINNING THE MEETING': 1,
#          'DISCUSSING ITEMS': 1,
#          'Discuss items on the agenda making sure to paraphrase and clarify as you move through the meeting.': 1,
#          'Jack Peterson:ÿÿBefore I begin the report I had like to get some ideas from you all. How do you feel about rural sales in your sales districts? I suggest we go round the table first to get all of your input.': 1,
#          'John Ruting:ÿIn my opinion we have been focusing too much on urban customers and their needs. The way I see things we need to return to our rural base by developing anÿadvertisingÿcampaign to focus on their particular needs.': 1,
#          "Donald Peters:ÿExcuse me I didn\\'t catch that. Could you repeat that please?": 1,
#          'Alice Linnes:ÿI just stated that we need to give our rural sales teams better customer information reporting.': 1,
#          'John Ruting:ÿI do not quite follow you. What exactly do you mean?': 1,
#          'Alice Linnes:ÿWell we provide our city sales staff with database information on all of our larger clients. We should be providing the same sort of knowledge on our rural customers to our sales staff there.': 1,
#          'Jack Peterson:ÿÿWould you like to add anything Jennifer?': 1,
#          'Jennifer Miles:ÿI must admit I never thought about rural sales that way before.': 1,
#          "Meeting Chairman:ÿÿUnfortunately We were running short of time. We\\'ll have to leave that to another time.": 1,
#          'Rural customers need special help to feel more valued.': 1,
#          'Our sales teams need more accurate information on our customers.': 1,
#          'We are considering specific data mining procedures to help deepen our understanding.': 1,
#          'These questions will help you ask for feedback andÿopinionsÿduring a conversation:': 1,
#          'ASKING FOR REPETITION': 1,
#          "If you do not understand what\\'s been said use one of these phrases:ÿ": 1,
#          "I didn\\'t catch that.": 1,
#          'Could you repeat that please?': 1,
#          'I missed that. Could you say it again please?': 2,
#          'Could you run that by me one more time?': 1,
#          'ASKING FOR CLARIFICATION': 1,
#          "If you\\'d like to check on some of the details use these phrases to ask for more details and get clarification:ÿ": 1,
#          'I am afraid I do notÿunderstand what your are getting at.': 1,
#          'CORRECTING INFORMATION': 1,
#          "At times it\\'s necessary to correct what someone else has said if it\\'s vital to the conversation. Use these phrases to correct information:": 1,
#          'last but not least': 1,
#          'today final call': 1,
#          'sounds good': 1,
#          'lets review the action point points': 1,
#          'why this was happened ': 1,
#          'what about the budget ': 1,
#          'show me the plan': 1,
#          'show me all the documentation': 1,
#          'let me look at the plan': 1,
#          'what happened to these issues and risks': 1,
#          'we need to discuss on agenda points': 1,
#          'what was happened on last meeting': 1,
#          'what is an outcome from previous meeting': 1,
#          'let me explain about the ': 1,
#          'purpose of the meeting': 1,
#          'tell me about the main issues and risks': 1,
#          'If we want to stay ahead of the pack We were going to have to work hard and continue to innovate.': 1,
#          'I think they got the government contract because of a backroom deal.': 1,
#          'I am not sure what a Super Bowl commercial costs but to give you a ballpark figure I had say about three million dollars.': 1,
#          "It\\'s a blue collar town with a lot of farmers and factory workers.": 1,
#          'The employees complained about the change in policy but the supervisor refused to cave in.': 1,
#          "It\\'s nice to go on business trips because it\\'s a change of pace.": 1,
#          'The charity fund raiser was supposed to raise three million dollars but we came up short.': 1,
#          "He was a diamond in the rough. He was intelligent and had great ideas but his management and English skills weren\\'t very good.": 1,
#          "A lot of people who inherit money waste it on stupid things. I guess it\\'s easy come easy go.": 1,
#          'My business partner and I split everything fifty-fifty.': 1,
#          'Bill Gates built Microsoft from the ground up.': 1,
#          "They\\'re not sure what their game plan is for the upcoming election.": 1,
#          "I always remember my coworkers\\' birthdays and get them a card or small gift. I like to get on people\\'s good side.": 1,
#          'The boss gave Brian a pat on the back for coming up with such a good idea.': 1,
#          "I can\\'t believe she gave us the thumbs down. I thought it was a great idea.": 1,
#          "I would love to get you a job at my company but my hands are tied. Management isn\\'t hiring any additional employees this year.": 1,
#          'She has to sell $action point5000 worth of products by the end of the month. She has her work cut out for her.': 1,
#          'Construction on the new site is in full swing now.': 1,
#          'We were not having a great year but at least We were in the black.': 1,
#          "I am not used to being in the driver\\'s seat. I should probably buy some management books.": 1,
#          "Our boss had been unhappy with Brian\\'s performance for a while but it was the last straw when he came to work three hours late without calling.": 1,
#          'I like my new position. I am starting to learn the ropes.': 1,
#          'Some people complain that millionaires avoid paying taxes by finding loopholes in tax laws.': 1,
#          'Apple lost some ground to Samsung last quarter.': 1,
#          "It\\'s a lose-lose situation. If they lay off more workers they\\'ll get bad press. If they do not lay off more workers they won\\'t be able to compete.": 1,
#          'She was tired of working a nine-to-five job so she took her savings and opened a restaurant.': 1,
#          'Taking the new job was a no brainer. They offered me more money a better schedule and more vacation days.': 1,
#          'They will let you try the product for free with no strings attached. If you do not like it there is no pressure to buy it.': 1,
#          "I told them I had be finished by the end of the day and it\\'s already 4:45. I need to get to work. There\\'s no time to lose.": 1,
#          'Our profits have been above our projected numbers for five months in a row. We were really on a roll.': 1,
#          "Let\\'s go over the details of what we agreed on to make sure We were on the same page.": 1,
#          'I read a lot to stay on top of the latest changes in my industry.': 1,
#          'I felt like I was out of the loop after being on vacation for two weeks.': 1,
#          'He played hardball to get where he is so I would be careful what you say and do around him.': 1,
#          "It\\'s not good to only invest in the stock market. You do not want to put all your eggs in one basket.": 1,
#          'They were trying to find investors without even having a business plan. They were putting the cart before the horse.': 1,
#          "He didn\\'t say that he wants to leave the company but I can read between the lines. He\\'s not happy here.": 1,
#          'The new law is going to create a lot of red tape and We were going to have to pay our lawyers a lot more money.': 1,
#          'I had ask for a raise but I do not want to rock the boat.': 1,
#          'We have round-the-clock production at all our manufacturing facilities.': 1,
#          'Everyone kept restating their opinions but nothing was agreed on. We were running around in circles.': 1,
#          "It\\'s a safe bet that smartphones will be much more advanced in key point0 years.": 1,
#          "She\\'s been a computer programmer for ten years. At this point programming is second nature to her.": 1,
#          'We do not always see eye to eye but I respect her opinions and appreciate her honesty.': 1,
#          "It\\'s best not to shoot down people\\'s ideas during a brainstorming session. The goal is to generate ideas not to criticize them.": 1,
#          "With their commission structure the sky\\'s the limit to what you can earn.": 1,
#          'We typically spend about key point5 minutes making small talk before we start our meetings.': 1,
#          'Once our largest competitor went out of business it was smooth sailing.': 1,
#          'We tried to change the dress code but Human Resources stood their ground.': 1,
#          "I just switched cable companies. They overcharged me for the first month\\'s service. They really started off on the wrong foot.": 1,
#          'We have a brand new state-of-the-art facility.': 1,
#          'I was trying to learn Portuguese but I got frustrated and threw in the towel.': 1,
#          'Winning the election is going to be an uphill battle. He does not have much support at the moment.': 1,
#          'John is more experienced and well respected so he had the upper hand in the argument.': 1,
#          "There are mostly manufacturing positions here. There aren\\'t many white-collar jobs.": 1,
#          'We were happy to get the contract and they were happy to get such a good price. It was a win-win situation.': 1,
#          "The company isn\\'t looking to hire someone who is going to try to make a lot of changes. They\\'re just looking for a yes man.": 1,
#          'I feel that..': 1,
#          'The way I see things..': 1,
#          'Do you think that..': 1,
#          'Mrs / Ms / Mr X can we get your input ?': 1,
#          'What do you think of .?ÿ': 1,
#          'Do you have something you would like to add?': 1,
#          "That\\'s interesting.": 1,
#          'I never thought about it that way beforeÿ': 1,
#          "I am afraid I didn\\'t quite catch that. Could you repeat what you just said": 1,
#          'Could you run that past me again': 1,
#          'I do not quite follow you.': 1,
#          'What exactly do you mean': 1,
#          "Could you explain to me how that\\'s going to work": 1,
#          "I can\\'t see what you\\'re getting at. Could we have some more details please": 1,
#          'Am I correct in thinking that ': 1,
#          'Welcoming participants to a meeting': 1,
#          'It?s nice to see everyone.': 1,
#          'It?s great to see everybody.': 1,
#          'I?m glad you could all make it today.': 1,
#          'Thanks for being here today.': 1,
#          'Hello everybody.': 1,
#          'It?s good to see you all.': 1,
#          'Saying who can?t attend the meeting': 1,
#          'I have apologies from Tina and Bob.': 1,
#          'Dieter has sent his apologies.': 1,
#          'Peter can?t make it either.': 1,
#          'Unfortunately Tim wasn?t able to make it today.': 1,
#          'Ursula can?t be with us today.': 1,
#          'Ursula has sent her apologies.': 1,
#          'I?m the business development manager.': 1,
#          'I?ve been with Burotech GmbH since decision00decision.': 1,
#          'I?ve worked for the company for four years.': 1,
#          'I?m based in the Cologne office.': 1,
#          'I work at our Vienna branch.': 1,
#          'What do you think about that What do we all think Do you want to start us off Do you want to come in here Would you like to make a point here Does anyone want to say anything on that Would you like to comment on that': 1,
#          'Why donot you introduce yourself to everyone Tell us a bit about yourself.Could you tell us all who you are and say something aboutyourself?': 1,
#          "Pete  let\\'s begin with the point of contention Would you explain what is it for the team\\'s reference": 1,
#          'That covers the most important point of the agenda': 1,
#          'That resolves the point of contention': 1,
#          'That resolves the bone of contention': 1,
#          'To be concise...': 1,
#          'In plain layman terms...': 1,
#          'I thank everyone for sparing some time off their busy schedules for this meeting': 1,
#          'I thank everyone for attending this important meeting': 1,
#          'I now open the meeting...': 1,
#          "It\\'s a pleasure to have Mark attend this meeting": 1,
#          "It\\'s a pleasure to have Mark chair this meeting": 1,
#          'I apologise for the absence of...': 1,
#          'Apologies for the absence of...': 1,
#          'Can we move on to the next item on the agenda': 1,
#          'Let me introduce (name of participant)  who will now take us through\x85': 1,
#          'Is there any item that we have missed discussing?': 1,
#          'Mark  Can I borrow you for a moment?': 1,
#          'Sorry for interrupting Mark  But can I have a moment with you?': 1,
#          'The way I look at it  I feel\x85': 1,
#          'From my perspective  I think that\x85': 1,
#          'Mark  what do you think will be the result of\x85': 1,
#          "I understand what you\\'re trying to say": 1,
#          "I think you\\'re beating around the bush. Could you be more specific as to how this would work": 1,
#          "Didn\\'t you meant that\x85": 1,
#          'Can you spell that for me please': 1,
#          'Mark  can we have your comments please': 1,
#          'Would be great if you all can revert with your feedback for this proposal': 1,
#          'we discussed the issue thread bear': 1,
#          'The issue needs to be deliberated before arriving at conclusion': 1,
#          'Our aim is to .': 1,
#          "First let\\'s go over the report from the last meeting which was held on (date)": 2,
#          "First let\\'s go over the minutes from our last meeting which was held last Tuesday. Jeff could you please read the notes?": 1,
#          'Daniel has agreed to take the minutes.': 1,
#          'Daniel has kindly agreed to give us a report on this matter.': 1,
#          'Daniel will lead point 1 Daniel point decision and Daniel point action point.': 1,
#          'We will hear a short report on each point first followed by a discussion round the table.': 1,
#          'The meeting is due to finish at.': 1,
#          "We\\'ll have to keep each item to ten minutes. Otherwise we\\'ll never get through.": 1,
#          "We may need to vote on item 5 if we can\\'t get a unanimous decision.": 1,
#          "I suggest we go round the table first to get everyone\\'s feedback. After that we\\'ll take a vote.": 1,
#          'I had like to hand over to Mark who is going to lead the next point.': 1,
#          'I had like to hand over to Jeff who is going to discuss the personnel issues.': 1,
#          'Stating the Principal Objectives': 1,
#          'We were here today to .': 1,
#          'I had like to make sure that we .': 1,
#          'Our main aim today is to .': 1,
#          'Here are the minutes from our last meeting which was on (date)': 1,
#          'Dealing with Recent Developments': 1,
#          'Jack how is the XYZ project coming along?': 1,
#          'Has everyone received a copy of the Tate Foundation report on current marketing trends?': 1,
#          "So if there is nothing else we need to discuss let\\'s move on to today\\'s agenda.": 1,
#          "If there are no further developments I had like to move on to today\\'s topic.": 1,
#          'Agreeing on the Ground Rules for the Meeting (contributions timing decision-making etc.)': 1,
#          'We will first hear a short report on each point first followed by a discussion of .': 1,
#          "Before we close today\\'s meeting let me just summarize the main points.": 1,
#          "Let me quickly go over today\\'s main points.": 1,
#          'To sum up ..': 1,
#          "OK why do not we quickly summarize what we\\'ve done today.": 1,
#          'In brief .': 1,
#          'Suggesting and Agreeing on Time Date and Place for the Next Meeting': 1,
#          'Can we set the date for the next meeting please?': 1,
#          "The meeting is finished we\\'ll see each other next .": 1,
#          'The meeting is closed.': 1,
#          'I declare the meeting closed.': 1,
#          'Agreeing': 1,
#          'I totally agree with you.': 2,
#          'Exactly!': 4,
#          "That\\'s (exactly) the way I feel.": 2,
#          'I have to agree with Daniel.': 2,
#          'Disagreeing': 1,
#          'Unfortunately I see it differently.': 2,
#          'Up to a point I agree with you but.': 3,
#          "(I am afraid) I can\\'t agree": 1,
#          'Advising and Suggesting': 1,
#          "Let\\'s.": 1,
#          'We should.': 2,
#          'Why do not you..': 2,
#          'How/What about.': 2,
#          'I suggest/recommend that.': 2,
#          'Clarifying': 1,
#          'Asking for Verification': 1,
#          'Is it true that.': 1,
#          'Keeping the Meeting On Target (time relevance decisions)': 1,
#          'We were running short of time.': 1,
#          'We need to take this decisions': 1,
#          'He is wrong we are running out of time': 1,
#          'You are right we need to move fast.': 1,
#          'I agree we need to move fast': 1,
#          'These project has been deliever': 1,
#          'You are inchanrge of important work': 1,
#          'We need to exchange the partnership': 1,
#          'These are urgent work': 1,
#          'We should not repreate same mistake': 1,
#          'Bill then I got there misdirect that Batman greetings all way way you should go': 1,
#          'bring all the consesus and discuss in meeting': 1,
#          'Constitution defin the final outcome': 1,
#          'Please convene this message': 1,
#          'we need to take a decision': 1,
#          'Work shoud be finished in motion': 1,
#          'You guys are fast mover': 1,
#          'These lists are opposer': 1,
#          'do not includes your other business': 1,
#          'These are the points of order': 1,
#          'Proposal dead line is very near': 1,
#          'Please mark proxy in his sheet': 1,
#          'You should have the resolution of problem': 1,
#          'These are secondry points': 1,
#          'I totally agree with you on that': 1,
#          'I think we are all on the same page here': 1,
#          'Yes I get what you?re saying': 1,
#          'I?m sorry but I think you may have that slightly wrong': 1,
#          'From our perspective. ': 1,
#          ' it?s a little different': 1,
#          'Let me explain': 1,
#          'can we discuss some other alternatives': 1,
#          'our bottom line is very clear on this one': 1,
#          'This is the deal breaker for us': 1,
#          'How will the new addition to our project affect the deadline that we have': 2,
#          'Are we making sure to incorporate ': 1,
#          'user feedback on the changes we are making': 1,
#          'I agree with Mark': 1,
#          'The correct approach is to send out the tools': 1,
#          'our partners before making it public to everyone': 1,
#          'I think we should introduce our new line of printers in August': 1,
#          'Many companies get more funding at this time': 1,
#          'students are school shopping': 1,
#          'Our target market will be more responsive to our ads during this time period."': 1,
#          'I think we can go either way ': 1,
#          'I believe both solutions will take care of it': 1,
#          "I didn\\'t understand why we are going to be late": 1,
#          'I thought we had everything planned out early. ': 1,
#          'What were the reasons again': 1,
#          'Can you elaborate on how this process can help the sales department': 2,
#          'Can you clarify the second step in your solution proposal ': 1,
#          'I do not understand why it is necessary': 1,
#          'What did you think about my presentation': 2,
#          'decision was taken to work on ': 1,
#          'choice is to use the the tool ': 1,
#          'agreement is work on ': 1,
#          'best choice is to take and work on ': 1,
#          'determination ': 1,
#          'taken judement on ': 1,
#          'verdict on ': 1,
#          'declaration on using': 1,
#          'preference arragement on deployment': 1,
#          'understanding installation': 1,
#          'lets settle to make working on ': 1,
#          'what is an alternative for ': 1,
#          'let choose ': 1,
#          'evalutation of startup ': 1,
#          'let substitute ': 1,
#          'selection of using the ': 1,
#          'acknowledgment on ': 1,
#          'after much deliberation we made a decision about what to have on our': 1,
#          'decidedness': 1,
#          'the resolving of a question by argument or reasoning': 1,
#          'the act of deciding definitely and firmly': 1,
#          'a woman of great courage and determination': 1,
#          'the definition of a concept in logic by its essential constituent': 1,
#          'he fixation of the destiny of undifferentiated embryonic tissue': 1,
#          'I still do a certain amount of work for them.': 1,
#          'They achieved varying degrees of success.': 1,
#          'While you canÿmeetÿnew people we also use the verb ?to meet? with deadlines.': 1,
#          'reach agreement on': 1,
#          'settle on': 1,
#          'negotiate': 2,
#          'work out': 1,
#          'arrive at': 1,
#          'yield to': 1,
#          'thrash out': 1,
#          'Since we have a few problems to discuss let?sÿmeet upÿinÿmy office': 1,
#          'An advantage is something that puts you in a better position than other people.': 1,
#          'Absolute means total and complete.': 1,
#          'It was impossible to pinpoint the cause ': 1,
#          'trying to pinpoint his precise location': 1,
#          'Accurate information measurements and statistics are correct to a very detailed level. ': 1,
#          'The first thing a project manager does is form a team of staff who are best for the project.': 1,
#          'Sometimes on a big project you may need to team up with other companies.': 1,
#          'You need a strong team for the project to succeed. Everyone will have to pitch in their ideas. We need each team member to share five ideas at the meeting on Monday.': 1,
#          'Since we will be starting from scratch on this project we will make the plan as we go along.': 1,
#          'A phase is one part in a series of action points or events. For example in a library project the design phase comes before the building phase.': 1,
#          'We must wait for the project team to define the phasesbefore we can start work.': 1,
#          'As soon as weÿkick offÿthe project we will be very busy': 1,
#          'Toÿmeet a deadlineÿmeans that you finish the task by the deadline': 1,
#          'The project manager is happy that the project isÿahead of scheduleÿand thanked the team for their hard work': 1,
#          'If the project goesÿaccording to schedule you can expect a nice bonus this year': 1,
#          'How should we advertise this new product? Let?sÿmake a planÿnow': 1,
#          'Changing the design now will take too much time': 1,
#          'If we want to include all these new ideas': 1,
#          'Since the project team is busy it might be a good idea toÿoutsource some tasksÿto another company': 1,
#          'Aÿtargetÿis something you are trying to achieve like a goal': 1,
#          ' this project will not be completed on time': 1,
#          'We must target to complete phase 1 before the year-end holidays when most people will be on vacation': 1,
#          'The project team can expect a free lunch if theyÿachieve the targetÿthis month': 1,
#          'The project manager has reminded us that toÿstay on budget': 1,
#          'we must remember to keep the costs as low as possible': 1,
#          'Management has agreed toÿincrease the budgetÿto cover the cost of testing the new car': 1,
#          'Okay everyone let?s check all the paperwork and clean up the project room thenÿwe?ll be ready toÿwrap up the project': 1,
#          'All that remains now isÿtoÿsign off the projectÿand take the whole project team out to celebrate': 1,
#          'Adjourn: to hold a meeting over until a later date.': 1,
#          "Adopt minutes: minutes are \\'adopted\\' when accepted by members and signed up by the chairman.": 1,
#          "Chairman\\'s Agenda: based upon the committee agenda but containing explanatory notes": 1,
#          'Collective Responsibility: a convention by which all committee members agree to abide by a majority decision': 1,
#          'Guillotine: cut short a debate ? usually in Parliament': 1,
#          'Honorary post: a duty performed without payment e.g. Honorary Secretary': 1,
#          'Lie on the table: leave item to be considered instead at the next meeting (see table)': 1,
#          "Resolution: the name given to a \\'motion\\' which has been passed or carried; used after the decision has been reached": 1,
#          'Standing Committee:ÿa committee which has an indefinite term of office': 1,
#          'Standing Orders: rules of procedure governing public sector meetings': 1,
#          'Table: to introduce a paper or schedule for noting': 1,
#          'Taken as read:ÿto save time it is assumed the members have already read the minutes': 1,
#          'Treasurer:ÿcommittee official responsible for its financial records and transaction points': 1,
#          'Unanimous: all being in favour': 1,
#          'Thank you all for coming at such short notice.ÿWe have a number of important matters on the agenda today. ': 1,
#          'how we can achieve that in the short-term': 1,
#          'We should take this decision': 1,
#          'These are the outcomes': 1,
#          'The process we need to follow': 1,
#          'These are my suggestions of increasing productivity ': 1,
#          'These are the reasions of getting late in the projects': 1,
#          'list isn?t performing as well as expected': 1,
#          'let?s talk aboutÿhow we can use social media toÿpromote our new product': 1,
#          'Excuse meÿcould you please clarifyÿwhat you said about the new travel policy': 1,
#          'I?m not sure I understand what you mean byÿletting the new staff handle these reports': 1,
#          'I?m sorry I don?t quite followÿthe calculation you just showed us': 1,
#          'I think we need to look atÿhow we can ensure this sort of production delay does not happen again': 1,
#          'I?m sorry but I don?t believe we?ve talked aboutÿhow we?re going to resolve the issue of manpower shortage': 2,
#          'This is what we?ve agreed on': 1,
#          "Meeting Chairman:ÿÿLet\\'s get started. We were here today to discuss ways of improving sales in rural market areas. First let\\'s go over the report from the last meeting which was held on June decision4th. Right Tom over to you.": 1,
#          'Tom Robbins:ÿThank you Mark. Let me just summarize the main points of the last meeting. We began the meeting by approving the changes in our sales reporting system discussed on May action point0th. After briefly revising the changes that will take place we moved on to a brainstorming session concerning after customer support improvements.': 1,
#          'MAKE SURE THAT EVERYONE HAS AN AGENDA OF THE MEETING AND STICK TO IT. REFER TO THE AGENDA FROM TIME TO TIME DURING THE MEETING TO KEEP THE DISCUSSION ON TRACK.': 1,
#          "Meeting Chairman:ÿÿThank you Tom. So if there is nothing else we need to discuss let\\'s move on to today\\'s agenda. Have you all received a copy of today\\'s agenda? If you do not mind I had like to skip item 1 and move on to item decision: Sales improvement in rural market areas. Jack has kindly agreed to give us a report on this matter. Jack?": 1,
#          ...})
